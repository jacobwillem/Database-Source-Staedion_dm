-- %% [markdown]
-- # Xtendis
--
-- ....
--
-- Jaco van der Wel, 11-02-2022

-- %% [markdown]
-- ## Voorbeeld query metadata dossiers

-- %%
SELECT DOC.idx_kast AS meta_kast
    , DOC.idx_documentdatum AS meta_datum_brief
    , DOS.idx_relatienummer AS meta_relatie_nr
    , DOC.idx_documentkenmerk AS meta_briefkenmerk
    , ('https://staedion.xtendis.nl/web/weblauncher.aspx?archiefnaam=Centraal&t_DOCUMENTID='::TEXT || DOC.documentid::TEXT) AS doc_hyperlink
    , DOC.idx_hoofdonderwerp as xtds_hoofdonderwerp
    , DOC.idx_subonderwerp as xtds_subonderwerp   
    , DOS.idx_klantnummer AS xtds_klantnummer     
    , DOC.idx_toelichting as xtds_toelichting
    , DOC.idx_afdeling as xtds_afdeling    
    , DOS.idx_clusternummer
    , DOS.idx_ogeh_nummer as xtds_ogeh_nummer
    -- select *
FROM extendis.dim_extendis_metadata_documenten as DOC
left outer join extendis.dim_extendis_metadata_dossiers as DOS 
on DOS.dossierid = DOC.dossierid 
WHERE DOC.idx_subonderwerp = 'Uitvoering werkzaamheden'
--and DOS.idx_clusternummer   = 'FT-1128'
--and lower(DOC.idx_toelichting) like 'akkoordverklaring'
    --and DOS.idx_ogeh_nummer = 'OGEH-0035880'
        AND date_part('year', DOC.idx_documentdatum) >= 2022 
;
-- Out:
-- (1285 row(s) affected)
-- Total execution time: 00:00:02.422
-- <table><tr><th>meta_kast</th><th>meta_datum_brief</th><th>meta_relatie_nr</th><th>meta_briefkenmerk</th><th>doc_hyperlink</th><th>xtds_hoofdonderwerp</th><th>xtds_subonderwerp</th><th>xtds_klantnummer</th><th>xtds_toelichting</th><th>xtds_afdeling</th><th>idx_clusternummer</th><th>xtds_ogeh_nummer</th></tr><tr><td>Huurders</td><td>2022-02-10T00:00:00</td><td>RLTS-0036684</td><td>NULL</td><td>https://staedion.xtendis.nl/web/weblauncher.aspx?archiefnaam=Centraal&amp;t_DOCUMENTID=4452074</td><td>Planmatig onderhoud</td><td>Uitvoering werkzaamheden</td><td>HRDR-0032664</td><td>woningopname voor energie label Hoefkade e.o.</td><td>Onderhoud en Vastgoed Secretariaat Bellevue</td><td>FT-1075</td><td>OGEH-0001079</td></tr><tr><td>Huurders</td><td>2022-02-10T00:00:00</td><td>RLTS-0027546</td><td>NULL</td><td>https://staedion.xtendis.nl/web/weblauncher.aspx?archiefnaam=Centraal&amp;t_DOCUMENTID=4452073</td><td>Planmatig onderhoud</td><td>Uitvoering werkzaamheden</td><td>HRDR-0023526</td><td>woningopname voor energie label Hoefkade e.o.</td><td>Onderhoud en Vastgoed Secretariaat Bellevue</td><td>FT-1075</td><td>OGEH-0001051</td></tr><tr><td>Huurders</td><td>2022-02-10T00:00:00</td><td>RLTS-0010124</td><td>NULL</td><td>https://staedion.xtendis.nl/web/weblauncher.aspx?archiefnaam=Centraal&amp;t_DOCUMENTID=4452071</td><td>Planmatig onderhoud</td><td>Uitvoering werkzaamheden</td><td>HRDR-0006104</td><td>woningopname voor energie label Hoefkade e.o.</td><td>Onderhoud en Vastgoed Secretariaat Bellevue</td><td>FT-1075</td><td>OGEH-0001130</td></tr><tr><td>Huurders</td><td>2022-02-10T00:00:00</td><td>RLTS-0027861</td><td>NULL</td><td>https://staedion.xtendis.nl/web/weblauncher.aspx?archiefnaam=Centraal&amp;t_DOCUMENTID=4452070</td><td>Planmatig onderhoud</td><td>Uitvoering werkzaamheden</td><td>HRDR-0023841</td><td>woningopname voor energie label Hoefkade e.o.</td><td>Onderhoud en Vastgoed Secretariaat Bellevue</td><td>FT-1075</td><td>OGEH-0001072</td></tr><tr><td>Huurders</td><td>2022-02-10T00:00:00</td><td>RLTS-0175676</td><td>NULL</td><td>https://staedion.xtendis.nl/web/weblauncher.aspx?archiefnaam=Centraal&amp;t_DOCUMENTID=4452069</td><td>Planmatig onderhoud</td><td>Uitvoering werkzaamheden</td><td>KLNT-0072935</td><td>woningopname voor energie label Hoefkade e.o.</td><td>Onderhoud en Vastgoed Secretariaat Bellevue</td><td>FT-1075</td><td>OGEH-0001068</td></tr><tr><td>Huurders</td><td>2022-02-10T00:00:00</td><td>RLTS-0236687</td><td>NULL</td><td>https://staedion.xtendis.nl/web/weblauncher.aspx?archiefnaam=Centraal&amp;t_DOCUMENTID=4452068</td><td>Planmatig onderhoud</td><td>Uitvoering werkzaamheden</td><td>KLNT-0087029</td><td>woningopname voor energie label Hoefkade e.o.</td><td>Onderhoud en Vastgoed Secretariaat Bellevue</td><td>FT-1075</td><td>OGEH-0001083</td></tr><tr><td>Huurders</td><td>2022-02-10T00:00:00</td><td>RLTS-0237936</td><td>NULL</td><td>https://staedion.xtendis.nl/web/weblauncher.aspx?archiefnaam=Centraal&amp;t_DOCUMENTID=4452067</td><td>Planmatig onderhoud</td><td>Uitvoering werkzaamheden</td><td>KLNT-0087303</td><td>woningopname voor energie label Hoefkade e.o.</td><td>Onderhoud en Vastgoed Secretariaat Bellevue</td><td>FT-1075</td><td>OGEH-0001089</td></tr><tr><td>Huurders</td><td>2022-02-10T00:00:00</td><td>RLTS-0004613</td><td>NULL</td><td>https://staedion.xtendis.nl/web/weblauncher.aspx?archiefnaam=Centraal&amp;t_DOCUMENTID=4452066</td><td>Planmatig onderhoud</td><td>Uitvoering werkzaamheden</td><td>HRDR-0000593</td><td>woningopname voor energie label Hoefkade e.o.</td><td>Onderhoud en Vastgoed Secretariaat Bellevue</td><td>FT-1075</td><td>OGEH-0001111</td></tr><tr><td>Huurders</td><td>2022-02-10T00:00:00</td><td>RLTS-0004454</td><td>NULL</td><td>https://staedion.xtendis.nl/web/weblauncher.aspx?archiefnaam=Centraal&amp;t_DOCUMENTID=4452065</td><td>Planmatig onderhoud</td><td>Uitvoering werkzaamheden</td><td>HRDR-0000434</td><td>woningopname voor energie label Hoefkade e.o.</td><td>Onderhoud en Vastgoed Secretariaat Bel ...

-- %% [markdown]
-- \## Nog een voorbeeld

-- %%
 select  DOS.idx_clusternummer
    , count(distinct DOS.idx_ogeh_nummer) as ogeh_nummers
    -- select *
FROM extendis.dim_extendis_metadata_documenten as DOC
left outer join extendis.dim_extendis_metadata_dossiers as DOS 
on DOS.dossierid = DOC.dossierid 
WHERE lower(DOC.idx_toelichting) like 'akkoordverklaring'
    AND date_part('year', DOC.idx_documentdatum) >= 2020 
   group by DOS.idx_clusternummer
